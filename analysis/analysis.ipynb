# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("/mnt/nvme/Projects/DataEngineer/Final/Task5/yellow_tripdata_2020-01.csv", low_memory=False)
data
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0             1.0  2020-01-01 00:28:15   2020-01-01 00:33:03              1.0
# 1             1.0  2020-01-01 00:35:39   2020-01-01 00:43:04              1.0
# 2             1.0  2020-01-01 00:47:41   2020-01-01 00:53:52              1.0
# 3             1.0  2020-01-01 00:55:23   2020-01-01 01:00:14              1.0
# 4             2.0  2020-01-01 00:01:58   2020-01-01 00:04:16              1.0
# ...           ...                  ...                   ...              ...
# 6405003       NaN  2020-01-31 22:51:00   2020-01-31 23:22:00              NaN
# 6405004       NaN  2020-01-31 22:10:00   2020-01-31 23:26:00              NaN
# 6405005       NaN  2020-01-31 22:50:07   2020-01-31 23:17:57              NaN
# 6405006       NaN  2020-01-31 22:25:53   2020-01-31 22:48:32              NaN
# 6405007       NaN  2020-01-31 22:44:00   2020-01-31 23:06:00              NaN
#
# ...

# %%
data[data["trip_distance"] < 0].shape
# Out:
# (2338, 18)

# %%
data[data["total_amount"] < 0].shape
# Out:
# (19505, 18)

# %%
data[data["passenger_count"].isnull()].shape
# Out:
# (65441, 18)

# %%
data1 = data[(data["trip_distance"] < 100) & (data["trip_distance"] >= 0) & (data["tip_amount"] <= 600) & (data["tip_amount"] >= 0)]

fig, ax = plt.subplots()

ax.set_xlabel('trip distance')
ax.set_ylabel('tip amount')

ax.scatter(x=data1['trip_distance'], y=data1['tip_amount']);

# %%
data2 = data[(data["passenger_count"] > 0) & (data["tip_amount"] <= 600) & (data["tip_amount"] >= 0)]

data2.plot.scatter(x='passenger_count', y='tip_amount').set_xticks(np.arange(0, 11, 1.0))
plt.show()

# %%
import seaborn as sns
sns.set()

ax = sns.scatterplot(data=data1, x="trip_distance", y="tip_amount")
ax.set(xlabel='trip distance', ylabel='tip amount')

pass
